# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr


# %config InlineBackend.figure_format = 'retina' #set 'png' here when working on notebook
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\mnan\\Desktop\\viz\\house_pred_ML'

# %%
train = pd.read_csv("data/train.csv",index_col = 0)
test = pd.read_csv("data/test.csv",index_col = 0)

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
pd.DataFrame(train.isnull().sum(),columns = ['missingVal']).query('missingVal>0').sort_values(by = 'missingVal',ascending = False)
# Out:
#               missingVal
# PoolQC              1453
# MiscFeature         1406
# Alley               1369
# Fence               1179
# FireplaceQu          690
# LotFrontage          259
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# GarageCond            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1

# %%
pd.DataFrame(test.isnull().sum(),columns = ['missingVal']).query('missingVal>0').sort_values(by = 'missingVal',ascending = False)
# Out:
#               missingVal
# PoolQC              1456
# MiscFeature         1408
# Alley               1352
# Fence               1169
# FireplaceQu          730
# LotFrontage          227
# GarageCond            78
# GarageYrBlt           78
# GarageQual            78
# GarageFinish          78
# GarageType            76
# BsmtCond              45
# BsmtExposure          44
# BsmtQual              44
# BsmtFinType1          42
# BsmtFinType2          42
# MasVnrType            16
# MasVnrArea            15
# MSZoning               4
# BsmtFullBath           2
# BsmtHalfBath           2
# Functional             2
# Utilities              2
# GarageCars             1
# GarageArea             1
# TotalBsmtSF            1
# KitchenQual            1
# BsmtUnfSF              1
# BsmtFinSF2             1
# BsmtFinSF1             1
# Exterior2nd            1
# Exterior1st            1
# SaleType               1

# %%
col_drop = list(pd.DataFrame(train.isnull().sum(),columns = ['missingVal'])
                .query('missingVal>0')
                .sort_values(by = 'missingVal',ascending = False)
                .index[:4])
print('Drop columns: %s because they contain too many missing values'%col_drop)
# Out:
# Drop columns: ['PoolQC', 'MiscFeature', 'Alley', 'Fence'] because they contain too many missing values

# %%
## drop cols
for col in col_drop:
    train = train.drop(col, 1)
    test = test.drop(col,1)
train = train.drop('Utilities', 1) ## no data variety in Utilities
test = test.drop('Utilities', 1)
train = train.drop('GarageYrBlt',1) ## 'GarageYrBlt' duplicate with YearBuilt
test = test.drop('GarageYrBlt',1)

# %%
## validate
train.shape[1]-test.shape[1]==1
# Out:
# True

# %% [markdown]
# ## Handle Missing Value

# %%
#other cols containing missing values
col_miss = list(pd.DataFrame(train.isnull().sum(),columns = ['missingVal'])
                .query('missingVal>0')
                .sort_values(by = 'missingVal',ascending = False)
                .index[5:])
print('dtype for col:')
for col in col_miss:
    print(dict(train.dtypes)[col],':',col)
# Out:
# dtype for col:
# object : GarageCond
# object : BsmtExposure
# object : BsmtFinType2
# object : BsmtQual
# object : BsmtCond
# object : BsmtFinType1
# object : MasVnrType
# float64 : MasVnrArea
# object : Electrical

# %%
test.ix[np.isnan(test['BsmtFullBath'])].filter(regex = 'Bsmt*',axis = 1)
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2121      NaN      NaN          NaN          NaN         NaN          NaN
# 2189      NaN      NaN          NaN          NaN         0.0          NaN
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# Id
# 2121         NaN        NaN          NaN           NaN           NaN
# 2189         0.0        0.0          0.0           NaN           NaN

# %%
num_col_miss = ['LotFrontage','GarageYrBlt','MasVnrArea']
cate_col_miss = [x for x in col_miss if x not in num_col_miss]
print('Three numeric cols contain missing values, they are %s \n%d categorical columns have missing values, they are %s'
     %(num_col_miss,len(cate_col_miss),cate_col_miss))
# Out:
# Three numeric cols contain missing values, they are ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']
# 8 categorical columns have missing values, they are ['GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'MasVnrType', 'Electrical']

# %%
from collections import Counter
print(Counter(list(test['GarageCars'])))
print(Counter(list(train['MiscVal'])))
# Out:
# Counter({'2.0': 770, '1.0': 407, '3.0': 193, '0.0': 77, '4.0': 11, '5.0': 1})
# Counter({0: 1408, 400: 11, 500: 8, 700: 5, 450: 4, 2000: 4, 600: 4, 480: 2, 1200: 2, 8300: 1, 620: 1, 3500: 1, 15500: 1, 2500: 1, 1400: 1, 1150: 1, 54: 1, 560: 1, 1300: 1, 350: 1, 800: 1})

# %%
# only NA in 'MasVnrType', 'Electrical' means missing value indeed
def false_na(train):
    train['GarageType']=train['GarageType'].replace({np.nan:'noGarage'})
    train['GarageFinish']=train['GarageFinish'].replace({np.nan:'noGarage'})
    train['GarageQual']=train['GarageQual'].replace({np.nan:'noGarage'})
    train['GarageCars']=train['GarageCars'].replace({np.nan:0})
    train['GarageArea']=train['GarageArea'].replace({np.nan:'0'})
    train['GarageCond']=train['GarageCond'].replace({np.nan:'noGarage'})
    #train['GarageYrBlt']=train['GarageYrBlt'].replace({np.nan:train['YearBuilt']})
    #train['GarageYrBlt'] = train['GarageYrBlt'].astype(str)
    
    train['BsmtExposure']=train['BsmtExposure'].replace({np.nan:'noBasement'})
    train['BsmtFinType2']=train['BsmtFinType2'].replace({np.nan:'noBasement'})
    train['BsmtFinType1']=train['BsmtFinType1'].replace({np.nan:'noBasement'})
    train['BsmtCond']=train['BsmtCond'].replace({np.nan:'noBasement'})
    train['BsmtQual']=train['BsmtQual'].replace({np.nan:'noBasement'})
    train['TotalBsmtSF']=train['TotalBsmtSF'].replace({np.nan:0})
    train['BsmtFinSF1']=train['BsmtFinSF1'].replace({np.nan:0})
    train['BsmtFinSF2']=train['BsmtFinSF2'].replace({np.nan:0})
    train['BsmtUnfSF']=train['BsmtUnfSF'].replace({np.nan:0})
    train['TotalBsmtSF']=train['TotalBsmtSF'].replace({np.nan:0})
    train['BsmtHalfBath']=train['BsmtHalfBath'].replace({np.nan:0})
    train['BsmtFullBath']=train['BsmtFullBath'].replace({np.nan:0})

    train['FireplaceQu']=train['FireplaceQu'].replace({np.nan:'noFireplace'})
    train['MasVnrType']=train['MasVnrType'].replace({np.nan:'noMasonryVeneer'})
    train['MasVnrArea']=train['MasVnrArea'].replace({np.nan:0})  
    train['MSZoning']=train['MSZoning'].replace({np.nan:'RL'})  
    train['Functional']=train['Functional'].replace({np.nan:'Typ'})  
    train['Exterior1st']=train['Exterior1st'].replace({np.nan:'VinylSd'})  
    train['Exterior2nd']=train['Exterior2nd'].replace({np.nan:'VinylSd'})  
    train['Electrical']=train['Electrical'].replace({np.nan:'SBrkr'})  
    train['SaleType']=train['SaleType'].replace({np.nan:'WD'}) 
    train['KitchenQual']=train['KitchenQual'].replace({np.nan:'TA'})  
    
    train['LotFrontage']=train['LotFrontage'].replace({np.nan:train['LotFrontage'].median()}) 
    
    train['MSSubClass'] = train['MSSubClass'].astype(str)
    train['OverallQual'] = train['OverallQual'].astype(str)
    train['OverallCond'] = train['OverallCond'].astype(str)
    train['YearBuilt'] = train['YearBuilt'].astype(str)
    train['OverallCond'] = train['OverallCond'].astype(str)
    train['YearRemodAdd'] = train['YearRemodAdd'].astype(str)
    train['MoSold'] = train['MoSold'].astype(str)
    train['YrSold'] = train['YrSold'].astype(str)
    train['BsmtFullBath'] = train['BsmtFullBath'].astype(str)
    train['BsmtHalfBath'] = train['BsmtHalfBath'].astype(str)
    train['FullBath'] = train['FullBath'].astype(str)
    train['HalfBath'] = train['HalfBath'].astype(str)
    train['BedroomAbvGr'] = train['BedroomAbvGr'].astype(str)
    train['KitchenAbvGr'] = train['KitchenAbvGr'].astype(str)
    train['TotRmsAbvGrd'] = train['TotRmsAbvGrd'].astype(str)
    train['Fireplaces'] = train['Fireplaces'].astype(str)

    
# assign missing vals in Functional to 'Typ'
# assign missing vals in Exterior1st to 'VinylSd'
# assign missing vals in Exterior2nd to 'VinylSd'
# assign missing vals in 'Electrical' to 'SBrkr'
# assign missing vals in 'SaleType' to 'WD'
    return train
# so two categorical cols ('MasVnrType', 'Electrical') contain missing value 
# and three numeric cols contain missing value

# %%
test = false_na(test)
train = false_na(train)
## validate
train.shape[1]-test.shape[1]==1
# Out:
# True

# %%
pd.DataFrame(train.isnull().sum(),columns = ['missingVal']).query('missingVal>0').sort_values(by = 'missingVal',ascending = False)
# Out:
# Empty DataFrame
# Columns: [missingVal]
# Index: []

# %%
pd.DataFrame(test.isnull().sum(),columns = ['missingVal']).query('missingVal>0').sort_values(by = 'missingVal',ascending = False)
# Out:
# Empty DataFrame
# Columns: [missingVal]
# Index: []

# %% [markdown]
# ** Now we've handled all missing values in both test and train set **
#
# Belows are exploration codes. We don't need them for actual data transformation

# %% [raw]
# fig = plt.figure(figsize = (10,4))
#
# ax1 = fig.add_subplot(121)
# train['LotFrontage'].hist()
#
# ax2 = fig.add_subplot(122)
# train['LotFrontage'].hist()
# plt.show()
# print(train['LotFrontage'].describe())
# print('median is %d' %train['LotFrontage'].median())
# print('--------------------')
# print(test['LotFrontage'].describe())
# print('median is %d' %test['LotFrontage'].median())
#
# ## assign median to LotFrontage
#
# from collections import Counter
# print(Counter(list(test['KitchenQual'])))
# print(Counter(list(train['KitchenQual'])))
#
# # assign missing vals in KitchenQual to 'TA'
#
#
# from collections import Counter
# print(Counter(list(test['Utilities'])))
# print(Counter(list(train['Utilities'])))
#
# ## we can delete the feature of Utilities
#
# print(Counter(list(test['MSZoning'])))
# print(Counter(list(train['MSZoning'])))
#
# # assign missing vals in MSZoning to 'RL'
#
# print(Counter(list(test['Functional'])))
# print(Counter(list(train['Functional'])))
#
# # assign missing vals in Functional to 'Typ'
#
# print(Counter(list(test['Exterior1st'])))
# print(Counter(list(train['Exterior1st'])))
#
# # assign missing vals in Exterior1st to 'VinylSd'
#
#
# print(Counter(list(test['Exterior2nd'])))
# print(Counter(list(train['Exterior2nd'])))
#
# # assign missing vals in Exterior2nd to 'VinylSd'
#
# print(Counter(list(test['SaleType'])))
# print(Counter(list(train['SaleType'])))
#
# # assign missing vals in 'SaleType' to 'WD'
#
# print(Counter(list(test['Electrical'])))
# print(Counter(list(train['Electrical'])))
#
# # assign missing vals in 'Electrical' to 'SBrkr'

# %%
## check data types
df_dtypes = pd.DataFrame(train.dtypes,columns=['train_dtypes']).join(pd.DataFrame(test.dtypes,columns=['test_dtypes']))
df_dtypes_diff = df_dtypes.ix[df_dtypes['train_dtypes'] != df_dtypes['test_dtypes']]

## GarageCars and GarageArea
## int64 to float

# %%
print(df_dtypes_diff.index[:6])
df_dtypes_diff
# Out:
# Index(['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath'],
#       dtype='object')
#              train_dtypes test_dtypes
# BsmtFinSF1          int64     float64
# BsmtFinSF2          int64     float64
# BsmtUnfSF           int64     float64
# TotalBsmtSF         int64     float64
# BsmtFullBath        int64     float64
# BsmtHalfBath        int64     float64
# GarageCars          int64     float64
# GarageArea          int64      object
# SalePrice           int64         NaN

# %%
for col in df_dtypes_diff.index[:6]:
    train[col] = train[col].astype('float')
train['GarageCars'] = train['GarageCars'].astype('float')
train['GarageCars'] = train['GarageCars'].astype('str')
test['GarageCars'] = test['GarageCars'].astype('str')

test['GarageArea'] = test['GarageArea'].astype('int64')
# check
df_dtypes0 = pd.DataFrame(train.dtypes,columns=['train_dtypes']).join(pd.DataFrame(test.dtypes,columns=['test_dtypes']))
df_dtypes0.ix[df_dtypes0['train_dtypes'] != df_dtypes0['test_dtypes']]
# Out:
#           train_dtypes test_dtypes
# SalePrice        int64         NaN

# %%
## validate
train.shape[1]-test.shape[1]==1
# Out:
# True

# %%
## let's check all categorical features
categorical_fea = df_dtypes0[df_dtypes0['test_dtypes']=='object'].index
extra_fea_test = []

for col in categorical_fea[:-2]:
    print(col)
    print(train[col].unique())
    print(test[col].unique())
    if not test[col].unique() in train[col].unique():
        print('column %s contrain extra values in test set'% col)
        extra_fea_test.append(col)
    print('---------------------')
# Out:
# MSZoning
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ['RH' 'RL' 'RM' 'FV' 'C (all)']
# ---------------------
# Street
# ['Pave' 'Grvl']
# ['Pave' 'Grvl']
# ---------------------
# LotShape
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ---------------------
# LandContour
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['Lvl' 'HLS' 'Bnk' 'Low']
# ---------------------
# LotConfig
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Inside' 'Corner' 'FR2' 'CulDSac' 'FR3']
# ---------------------
# LandSlope
# ['Gtl' 'Mod' 'Sev']
# ['Gtl' 'Mod' 'Sev']
# ---------------------
# Neighborhood
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ['NAmes' 'Gilbert' 'StoneBr' 'BrDale' 'NPkVill' 'NridgHt' 'Blmngtn'
#  'NoRidge' 'Somerst' 'SawyerW' 'Sawyer' 'NWAmes' 'OldTown' 'BrkSide'
#  'ClearCr' 'SWISU' 'Edwards' 'CollgCr' 'Crawfor' 'Blueste' 'IDOTRR'
#  'Mitchel' 'Timber' 'MeadowV' 'Veenker']
# column Neighborhood contrain extra values in test set
# ---------------------
# Condition1
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ['Feedr' 'Norm' 'PosN' 'RRNe' 'Artery' 'RRNn' 'PosA' 'RRAn' 'RRAe']
# ---------------------
# Condition2
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# ['Norm' 'Feedr' 'PosA' 'PosN' 'Artery']
# column Condition2 contrain extra values in test set
# ---------------------
# BldgType
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# ['1Fam' 'TwnhsE' 'Twnhs' 'Duplex' '2fmCon']
# ---------------------
# HouseStyle
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# ['1Story' '2Story' 'SLvl' '1.5Fin' 'SFoyer' '2.5Unf' '1.5Unf']
# column HouseStyle contrain extra values in test set
# ---------------------
# RoofStyle
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ['Gable' 'Hip' 'Gambrel' 'Flat' 'Mansard' 'Shed']
# ---------------------
# RoofMatl
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll' 'ClyTile']
# ['CompShg' 'Tar&Grv' 'WdShake' 'WdShngl']
# column RoofMatl contrain extra values in test set
# ---------------------
# Exterior1st
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'CemntBd' 'WdShing'
#  'BrkFace' 'AsbShng' 'BrkComm' 'Stucco' 'AsphShn' 'CBlock']
# column Exterior1st contrain extra values in test set
# ---------------------
# Exterior2nd
# ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone' 'Other'
#  'CBlock']
# ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'Brk Cmn' 'CmentBd'
#  'ImStucc' 'Wd Shng' 'AsbShng' 'Stucco' 'CBlock' 'BrkFace' 'AsphShn'
#  'Stone']
# column Exterior2nd contrain extra values in test set
# ---------------------
# MasVnrType
# ['BrkFace' 'None' 'Stone' 'BrkCmn' 'noMasonryVeneer']
# ['None' 'BrkFace' 'Stone' 'BrkCmn' 'noMasonryVeneer']
# ---------------------
# ExterQual
# ['Gd' 'TA' 'Ex' 'Fa']
# ['TA' 'Gd' 'Ex' 'Fa']
# ---------------------
# ExterCond
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# ---------------------
# Foundation
# ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
# ['CBlock' 'PConc' 'BrkTil' 'Stone' 'Slab' 'Wood']
# ---------------------
# BsmtQual
# ['Gd' 'TA' 'Ex' 'noBasement' 'Fa']
# ['TA' 'Gd' 'Ex' 'Fa' 'noBasement']
# ---------------------
# BsmtCond
# ['TA' 'Gd' 'noBasement' 'Fa' 'Po']
# ['TA' 'Po' 'Fa' 'Gd' 'noBasement']
# ---------------------
# BsmtExposure
# ['No' 'Gd' 'Mn' 'Av' 'noBasement']
# ['No' 'Gd' 'Mn' 'Av' 'noBasement']
# ---------------------
# BsmtFinType1
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'noBasement' 'LwQ']
# ['Rec' 'ALQ' 'GLQ' 'Unf' 'BLQ' 'LwQ' 'noBasement']
# ---------------------
# BsmtFinType2
# ['Unf' 'BLQ' 'noBasement' 'ALQ' 'Rec' 'LwQ' 'GLQ']
# ['LwQ' 'Unf' 'Rec' 'BLQ' 'GLQ' 'ALQ' 'noBasement']
# column BsmtFinType2 contrain extra values in test set
# ---------------------
# Heating
# ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# ['GasA' 'GasW' 'Grav' 'Wall']
# column Heating contrain extra values in test set
# ---------------------
# HeatingQC
# ['Ex' 'Gd' 'TA' 'Fa' 'Po']
# ['TA' 'Gd' 'Ex' 'Fa' 'Po']
# ---------------------
# CentralAir
# ['Y' 'N']
# ['Y' 'N']
# ---------------------
# Electrical
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# ['SBrkr' 'FuseA' 'FuseF' 'FuseP']
# column Electrical contrain extra values in test set
# ---------------------
# KitchenQual
# ['Gd' 'TA' 'Ex' 'Fa']
# ['TA' 'Gd' 'Ex' 'Fa']
# ---------------------
# Functional
# ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
# ['Typ' 'Min2' 'Min1' 'Mod' 'Maj1' 'Sev' 'Maj2']
# ---------------------
# FireplaceQu
# ['noFireplace' 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# ['noFireplace' 'TA' 'Gd' 'Po' 'Fa' 'Ex']
# ---------------------
# GarageType
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'noGarage' 'Basment' '2Types']
# ['Attchd' 'Detchd' 'BuiltIn' 'noGarage' 'Basment' '2Types' 'CarPort']
# ---------------------
# GarageFinish
# ['RFn' 'Unf' 'Fin' 'noGarage']
# ['Unf' 'Fin' 'RFn' 'noGarage']
# ---------------------
# GarageCars
# ['2.0' '3.0' '1.0' '0.0' '4.0']
# ['1.0' '2.0' '3.0' '0.0' '4.0' '5.0']
# column GarageCars contrain extra values in test set
# ---------------------
# GarageQual
# ['TA' 'Fa' 'Gd' 'noGarage' 'Ex' 'Po']
# ['TA' 'noGarage' 'Fa' 'Gd' 'Po']
# column GarageQual contrain extra values in test set
# ---------------------
# GarageCond
# ['TA' 'Fa' 'noGarage' 'Gd' 'Po' 'Ex']
# ['TA' 'noGarage' 'Fa' 'Gd' 'Po' 'Ex']
# ---------------------
# PavedDrive
# ['Y' 'N' 'P']
# ['Y' 'N' 'P']
# ---------------------
# C:\Users\mnan\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %%
extra_fea_test
# Out:
# ['Neighborhood',
#  'Condition2',
#  'HouseStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'BsmtFinType2',
#  'Heating',
#  'Electrical',
#  'GarageCars',
#  'GarageQual']

# %%
df_dtypes = pd.DataFrame(train.dtypes,columns = ['dtypes'])
numeric_cols = df_dtypes[df_dtypes['dtypes']!='object'].index
cate_cols = df_dtypes[df_dtypes['dtypes']=='object'].index

# %%
print(len(numeric_cols))
print(numeric_cols)
# Out:
# 35
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
g = sns.pairplot(train[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd']], diag_kind="hist")
for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45)

# %%
corr_price = dict()
for col in numeric_cols:
    corr_price[col] = np.corrcoef(train[col],train['SalePrice'])[0,1]
fig = pd.DataFrame.from_dict(data = corr_price,orient = 'index').sort_values(by = 0).plot(
    kind = 'bar',figsize = (8,4))
fig.legend(['correlation with price'],loc = 'best')

# %%
for i in range(len(numeric_cols)):
    columni = numeric_cols[i]
    for j in range(i+1,len(numeric_cols)-i):
        columnj = numeric_cols[j]
        corij = np.corrcoef(train[columni],train[columnj])[0,1]
        if corij > 0.3:
            print("%s is %s correlated with %s" % 
                  (columni,corij,columnj))
      
plt.matshow(train[numeric_cols].corr())
plt.show()
plt.close()
# Out:
# MSSubClass is 0.30788572076 correlated with 2ndFlrSF
# LotFrontage is 0.304522170744 correlated with LotArea
# LotFrontage is 0.363472311641 correlated with TotalBsmtSF
# LotFrontage is 0.413772532438 correlated with 1stFlrSF
# LotFrontage is 0.368007439154 correlated with GrLivArea
# LotFrontage is 0.320517656206 correlated with TotRmsAbvGrd
# LotFrontage is 0.323510928812 correlated with GarageArea
# OverallQual is 0.572322768962 correlated with YearBuilt
# OverallQual is 0.550683924194 correlated with YearRemodAdd
# OverallQual is 0.407252123524 correlated with MasVnrArea
# OverallQual is 0.308158926906 correlated with BsmtUnfSF
# OverallQual is 0.537808498612 correlated with TotalBsmtSF
# OverallQual is 0.476223829078 correlated with 1stFlrSF
# OverallQual is 0.593007430029 correlated with GrLivArea
# OverallQual is 0.550599709368 correlated with FullBath
# OverallQual is 0.427452343278 correlated with TotRmsAbvGrd
# OverallQual is 0.396765037952 correlated with Fireplaces
# OverallQual is 0.562021756613 correlated with GarageArea
# OverallQual is 0.308818823359 correlated with OpenPorchSF
# YearBuilt is 0.592854976344 correlated with YearRemodAdd
# YearBuilt is 0.311600106829 correlated with MasVnrArea
# YearBuilt is 0.391452002066 correlated with TotalBsmtSF
# YearBuilt is 0.468270787173 correlated with FullBath
# YearBuilt is 0.478953819893 correlated with GarageArea
# YearRemodAdd is 0.439046483872 correlated with FullBath
# YearRemodAdd is 0.371599809497 correlated with GarageArea
# MasVnrArea is 0.360067368054 correlated with TotalBsmtSF
# MasVnrArea is 0.339850413683 correlated with 1stFlrSF
# MasVnrArea is 0.388052052222 correlated with GrLivArea
# MasVnrArea is 0.370884152809 correlated with GarageArea
# BsmtFinSF1 is 0.522396051992 correlated with TotalBsmtSF
# BsmtFinSF1 is 0.445862656092 correlated with 1stFlrSF
# BsmtFinSF1 is 0.649211753574 correlated with BsmtFullBath
# BsmtUnfSF is 0.415359605182 correlated with TotalBsmtSF
# BsmtUnfSF is 0.317987438353 correlated with 1stFlrSF
# TotalBsmtSF is 0.819529975005 correlated with 1stFlrSF
# TotalBsmtSF is 0.454868202548 correlated with GrLivArea
# TotalBsmtSF is 0.307350553736 correlated with BsmtFullBath
# TotalBsmtSF is 0.323722413607 correlated with FullBath
# TotalBsmtSF is 0.339519323899 correlated with Fireplaces
# 1stFlrSF is 0.566023968936 correlated with GrLivArea
# 1stFlrSF is 0.380637494974 correlated with FullBath
# 1stFlrSF is 0.409515978867 correlated with TotRmsAbvGrd
# 2ndFlrSF is 0.687501064167 correlated with GrLivArea
# 2ndFlrSF is 0.421377982876 correlated with FullBath
# 2ndFlrSF is 0.609707300272 correlated with HalfBath
# 2ndFlrSF is 0.502900613346 correlated with BedroomAbvGr
# GrLivArea is 0.630011646251 correlated with FullBath
# GrLivArea is 0.415771636105 correlated with HalfBath

# %%
for i in range(len(train_dummies.columns.tolist())):
    columni = train_dummies.columns.tolist()[i]
    for j in range(i+1,len(train_dummies.columns.tolist())-i):
        columnj = train_dummies.columns.tolist()[j]
        corij = np.corrcoef(train_dummies[columni],train_dummies[columnj])[0,1]
        if corij>=0.3:
            print("%s is %s correlated with %s" % 
                  (train_dummies.columns.tolist()[i],corij,train_dummies.columns.tolist()[j]))
      
plt.matshow(train_dummies.corr())
plt.show()
plt.close()
# Out:
# MSSubClass is 0.30788572076 correlated with 2ndFlrSF
# MSSubClass is 0.444510654803 correlated with BldgType_2fmCon
# MSSubClass is 0.415158527613 correlated with BldgType_Twnhs
# MSSubClass is 0.524847172735 correlated with BldgType_TwnhsE
# MSSubClass is 0.348910263079 correlated with HouseStyle_2Story
# LotFrontage is 0.304522170744 correlated with LotArea
# LotFrontage is 0.363472311641 correlated with TotalBsmtSF
# LotFrontage is 0.413772532438 correlated with 1stFlrSF
# LotFrontage is 0.368007439154 correlated with GrLivArea
# LotFrontage is 0.320517656206 correlated with TotRmsAbvGrd
# LotFrontage is 0.323510928812 correlated with GarageArea
# LotFrontage is 0.33477085314 correlated with SalePrice
# LotFrontage is 0.323090525294 correlated with MSZoning_RL
# LotFrontage is 0.37063966903 correlated with BldgType_1Fam
# LotArea is 0.359474567303 correlated with LandContour_Low
# LotArea is 0.540379788506 correlated with LandSlope_Sev
# OverallQual is 0.572322768962 correlated with YearBuilt
# OverallQual is 0.550683924194 correlated with YearRemodAdd
# OverallQual is 0.407252123524 correlated with MasVnrArea
# OverallQual is 0.308158926906 correlated with BsmtUnfSF
# OverallQual is 0.537808498612 correlated with TotalBsmtSF
# OverallQual is 0.476223829078 correlated with 1stFlrSF
# OverallQual is 0.593007430029 correlated with GrLivArea
# OverallQual is 0.550599709368 correlated with FullBath
# OverallQual is 0.427452343278 correlated with TotRmsAbvGrd
# OverallQual is 0.396765037952 correlated with Fireplaces
# OverallQual is 0.562021756613 correlated with GarageArea
# OverallQual is 0.308818823359 correlated with OpenPorchSF
# OverallQual is 0.790981600584 correlated with SalePrice
# OverallQual is 0.368723817426 correlated with Neighborhood_NridgHt
# OverallQual is 0.349259518888 correlated with Exterior1st_VinylSd
# OverallQual is 0.352151677276 correlated with Exterior2nd_VinylSd
# OverallQual is 0.331583504456 correlated with MasVnrType_Stone
# OverallQual is 0.384495380155 correlated with ExterQual_Ex
# OverallQual is 0.547731192968 correlated with ExterQual_Gd
# OverallQual is 0.568210671646 correlated with Foundation_PConc
# OverallQual is 0.470779582252 correlated with BsmtQual_Ex
# OverallQual is 0.347564282808 correlated with BsmtQual_Gd
# OverallQual is 0.433448127486 correlated with BsmtFinType1_GLQ
# OverallQual is 0.458225273089 correlated with HeatingQC_Ex
# OverallQual is 0.425750359674 correlated with KitchenQual_Ex
# OverallQual is 0.409133588812 correlated with KitchenQual_Gd
# OverallQual is 0.341275476616 correlated with FireplaceQu_Gd
# OverallQual is 0.357994003499 correlated with GarageType_Attchd
# OverallQual is 0.394996447308 correlated with GarageFinish_Fin
# OverallQual is 0.503650199842 correlated with GarageCars_3.0
# OverallQual is 0.300819373974 correlated with GarageCond_TA
# OverallQual is 0.327411843529 correlated with SaleType_New
# OverallCond is 0.334537970367 correlated with ExterCond_Gd
# YearBuilt is 0.592854976344 correlated with YearRemodAdd
# YearBuilt is 0.311600106829 correlated with MasVnrArea
# YearBuilt is 0.391452002066 correlated with TotalBsmtSF
# YearBuilt is 0.468270787173 correlated with FullBath
# YearBuilt is 0.478953819893 correlated with GarageArea
# YearBuilt is 0.522897332879 correlated with SalePrice
# YearBuilt is 0.518734206594 correlated with Exterior1st_VinylSd
# YearBuilt is 0.514608561295 correlated with Exterior2nd_VinylSd
# YearBuilt is 0.557909879541 correlated with ExterQual_Gd
# YearBuilt is 0.651199277474 correlated with Foundation_PConc
# YearBuilt is 0.319394437409 correlated with BsmtQual_Ex
# YearBuilt is 0.559858122301 correlated with BsmtQual_Gd
# YearBuilt is 0.479424705096 correlated with BsmtFinType1_GLQ
# YearBuilt is 0.465356366956 correlated with HeatingQC_Ex
# YearBuilt is 0.381830751799 correlated with CentralAir_Y
# YearBuilt is 0.345107685843 correlated with Electrical_SBrkr
# YearBuilt is 0.435314869327 correlated with KitchenQual_Gd
# YearBuilt is 0.472229494914 correlated with GarageType_Attchd
# YearBuilt is 0.393236929779 correlated with GarageFinish_Fin
# YearBuilt is 0.314220574034 correlated with GarageFinish_RFn
# YearBuilt is 0.32419236599 correlated with GarageCars_3.0
# YearBuilt is 0.383603477091 correlated with GarageQual_TA
# YearBuilt is 0.350350156753 correlated with GarageCond_TA
# YearBuilt is 0.433060189363 correlated with PavedDrive_Y
# YearBuilt is 0.346953571784 correlated with SaleType_New
# YearRemodAdd is 0.439046483872 correlated with FullBath
# YearRemodAdd is 0.371599809497 correlated with GarageArea
# YearRemodAdd is 0.507100967111 correlated with SalePrice
# YearRemodAdd is 0.484530163394 correlated with Exterior1st_VinylSd
# YearRemodAdd is 0.484835777245 correlated with Exterior2nd_VinylSd
# YearRemodAdd is 0.531482204744 correlated with ExterQual_Gd
# YearRemodAdd is 0.569728388935 correlated with Foundation_PConc
# YearRemodAdd is 0.422698131003 correlated with BsmtQual_Gd
# YearRemodAdd is 0.401679054111 correlated with BsmtFinType1_GLQ
# YearRemodAdd is 0.516286188727 correlated with HeatingQC_Ex
# YearRemodAdd is 0.354558137737 correlated with Electrical_SBrkr
# YearRemodAdd is 0.533628451753 correlated with KitchenQual_Gd
# YearRemodAdd is 0.3285194697 correlated with GarageFinish_Fin
# YearRemodAdd is 0.325647443588 correlated with SaleType_New
# MasVnrArea is 0.360067368054 correlated with TotalBsmtSF
# MasVnrArea is 0.339850413683 correlated with 1stFlrSF
# MasVnrArea is 0.388052052222 correlated with GrLivArea
# MasVnrArea is 0.370884152809 correlated with GarageArea
# MasVnrArea is 0.472614499005 correlated with SalePrice
# MasVnrArea is 0.571328214228 correlated with MasVnrType_BrkFace
# MasVnrArea is 0.340645266248 correlated with ExterQual_Ex
# MasVnrArea is 0.333127810545 correlated with BsmtQual_Ex
# MasVnrArea is 0.380393293143 correlated with GarageCars_3.0
# BsmtFinSF1 is 0.522396051992 correlated with TotalBsmtSF
# BsmtFinSF1 is 0.445862656092 correlated with 1stFlrSF
# BsmtFinSF1 is 0.649211753574 correlated with BsmtFullBath
# BsmtFinSF1 is 0.386419806242 correlated with SalePrice
# BsmtFinSF1 is 0.336150961129 correlated with BsmtExposure_Gd
# BsmtFinSF1 is 0.497435674391 correlated with BsmtFinType1_GLQ
# BsmtFinSF2 is 0.30221920961 correlated with BsmtFinType1_LwQ
# BsmtFinSF2 is 0.412707291545 correlated with BsmtFinType2_ALQ
# BsmtFinSF2 is 0.373081602474 correlated with BsmtFinType2_GLQ
# BsmtFinSF2 is 0.42037264096 correlated with BsmtFinType2_Rec
# BsmtUnfSF is 0.415359605182 correlated with TotalBsmtSF
# BsmtUnfSF is 0.317987438353 correlated with 1stFlrSF
# BsmtUnfSF is 0.602706583597 correlated with BsmtFinType1_Unf
# BsmtUnfSF is 0.312075676341 correlated with BsmtFinType2_Unf
# TotalBsmtSF is 0.819529975005 correlated with 1stFlrSF
# TotalBsmtSF is 0.454868202548 correlated with GrLivArea
# TotalBsmtSF is 0.307350553736 correlated with BsmtFullBath
# TotalBsmtSF is 0.323722413607 correlated with FullBath
# TotalBsmtSF is 0.339519323899 correlated with Fireplaces
# TotalBsmtSF is 0.486665463774 correlated with GarageArea
# TotalBsmtSF is 0.613580551559 correlated with SalePrice
# TotalBsmtSF is 0.339155016629 correlated with HouseStyle_1Story
# TotalBsmtSF is 0.301620334205 correlated with RoofMatl_ClyTile
# TotalBsmtSF is 0.300793482412 correlated with MasVnrType_Stone
# TotalBsmtSF is 0.345967598538 correlated with ExterQual_Ex
# TotalBsmtSF is 0.307700847959 correlated with Foundation_PConc
# TotalBsmtSF is 0.403166081853 correlated with BsmtQual_Ex
# TotalBsmtSF is 0.317396066338 correlated with BsmtFinType1_GLQ
# TotalBsmtSF is 0.360271152548 correlated with KitchenQual_Ex
# TotalBsmtSF is 0.380596411113 correlated with GarageType_Attchd
# TotalBsmtSF is 0.419653841145 correlated with GarageCars_3.0
# 1stFlrSF is 0.566023968936 correlated with GrLivArea
# 1stFlrSF is 0.380637494974 correlated with FullBath
# 1stFlrSF is 0.409515978867 correlated with TotRmsAbvGrd
# 1stFlrSF is 0.41053108466 correlated with Fireplaces
# 1stFlrSF is 0.489781654104 correlated with GarageArea
# 1stFlrSF is 0.605852184692 correlated with SalePrice
# 1stFlrSF is 0.304731046263 correlated with MSZoning_RL
# 1stFlrSF is 0.37194603135 correlated with HouseStyle_1Story
# 1stFlrSF is 0.323994458329 correlated with RoofStyle_Hip
# 1stFlrSF is 0.32962411005 correlated with ExterQual_Ex
# 1stFlrSF is 0.37738676851 correlated with BsmtQual_Ex
# 1stFlrSF is 0.347257466047 correlated with KitchenQual_Ex
# 1stFlrSF is 0.352864991448 correlated with GarageType_Attchd
# 1stFlrSF is 0.38881571632 correlated with GarageCars_3.0
# 2ndFlrSF is 0.687501064167 correlated with GrLivArea
# 2ndFlrSF is 0.421377982876 correlated with FullBath
# 2ndFlrSF is 0.609707300272 correlated with HalfBath
# 2ndFlrSF is 0.502900613346 correlated with BedroomAbvGr
# 2ndFlrSF is 0.616422635492 correlated with TotRmsAbvGrd
# 2ndFlrSF is 0.319333802832 correlated with SalePrice
# 2ndFlrSF is 0.809149779865 correlated with HouseStyle_2Story
# 2ndFlrSF is 0.376067104486 correlated with GarageType_BuiltIn
# LowQualFinSF is 0.590462278508 correlated with HouseStyle_2.5Fin
# GrLivArea is 0.630011646251 correlated with FullBath
# GrLivArea is 0.415771636105 correlated with HalfBath
# GrLivArea is 0.521269510919 correlated with BedroomAbvGr
# GrLivArea is 0.825489374309 correlated with TotRmsAbvGrd
# GrLivArea is 0.461679133761 correlated with Fireplaces
# GrLivArea is 0.468997477323 correlated with GarageArea
# GrLivArea is 0.330223961712 correlated with OpenPorchSF
# GrLivArea is 0.708624477613 correlated with SalePrice
# GrLivArea is 0.32144951198 correlated with Neighborhood_NoRidge
# GrLivArea is 0.468835993277 correlated with HouseStyle_2Story
# GrLivArea is 0.302515752098 correlated with ExterQual_Gd
# GrLivArea is 0.309961959815 correlated with BsmtQual_Ex
# GrLivArea is 0.30660364517 correlated with KitchenQual_Ex
# GrLivArea is 0.407585268194 correlated with GarageCars_3.0
# BsmtFullBath is 0.450440983584 correlated with BsmtFinType1_GLQ
# FullBath is 0.363251983023 correlated with BedroomAbvGr
# FullBath is 0.554784253533 correlated with TotRmsAbvGrd
# FullBath is 0.405656208454 correlated with GarageArea
# FullBath is 0.560663762748 correlated with SalePrice
# FullBath is 0.358106583225 correlated with HouseStyle_2Story
# FullBath is 0.312311586109 correlated with Exterior1st_VinylSd
# FullBath is 0.303980654355 correlated with Exterior2nd_VinylSd
# FullBath is 0.42511948322 correlated with ExterQual_Gd
# FullBath is 0.461666827239 correlated with Foundation_PConc
# FullBath is 0.384593182302 correlated with BsmtQual_Gd
# FullBath is 0.33654041904 correlated with HeatingQC_Ex
# FullBath is 0.372641928269 correlated with KitchenQual_Gd
# FullBath is 0.30841193997 correlated with GarageCars_3.0
# HalfBath is 0.343414857541 correlated with TotRmsAbvGrd
# HalfBath is 0.623398955752 correlated with HouseStyle_2Story
# BedroomAbvGr is 0.676619935743 correlated with TotRmsAbvGrd
# BedroomAbvGr is 0.34381526657 correlated with HouseStyle_2Story
# KitchenAbvGr is 0.357126235913 correlated with BldgType_2fmCon
# KitchenAbvGr is 0.680843830047 correlated with BldgType_Duplex
# TotRmsAbvGrd is 0.326114480177 correlated with Fireplaces
# TotRmsAbvGrd is 0.337822120637 correlated with GarageArea
# TotRmsAbvGrd is 0.533723155582 correlated with SalePrice
# TotRmsAbvGrd is 0.430929732318 correlated with HouseStyle_2Story
# TotRmsAbvGrd is 0.362348637794 correlated with GarageCars_3.0
# Fireplaces is 0.466928836752 correlated with SalePrice
# Fireplaces is 0.496683814711 correlated with FireplaceQu_Gd
# Fireplaces is 0.456126291934 correlated with FireplaceQu_TA
# GarageArea is 0.623431438918 correlated with SalePrice
# GarageArea is 0.301139048711 correlated with Neighborhood_NridgHt
# GarageArea is 0.370531198753 correlated with ExterQual_Gd
# GarageArea is 0.388871402453 correlated with Foundation_PConc
# GarageArea is 0.370222842226 correlated with BsmtQual_Ex
# GarageArea is 0.310815453139 correlated with BsmtFinType1_GLQ
# GarageArea is 0.303139683791 correlated with HeatingQC_Ex
# GarageArea is 0.595957233344 correlated with GarageCars_3.0
# GarageArea is 0.473051735967 correlated with GarageQual_TA
# WoodDeckSF is 0.324413444568 correlated with SalePrice
# OpenPorchSF is 0.315856227116 correlated with SalePrice
# PoolArea is 0.311084338642 correlated with RoofMatl_ClyTile
# MiscVal is 0.43584123358 correlated with Condition2_RRAe
# MiscVal is 0.306668113337 correlated with RoofStyle_Shed
# SalePrice is 0.330423625765 correlated with Neighborhood_NoRidge
# SalePrice is 0.402148598175 correlated with Neighborhood_NridgHt
# SalePrice is 0.305008802478 correlated with Exterior1st_VinylSd
# SalePrice is 0.306388880871 correlated with Exterior2nd_VinylSd
# SalePrice is 0.330475646543 correlated with MasVnrType_Stone
# SalePrice is 0.451164330223 correlated with ExterQual_Ex
# SalePrice is 0.452466127845 correlated with ExterQual_Gd
# SalePrice is 0.497733752587 correlated with Foundation_PConc
# SalePrice is 0.553104847009 correlated with BsmtQual_Ex
# SalePrice is 0.307298314587 correlated with BsmtExposure_Gd
# SalePrice is 0.434597346883 correlated with BsmtFinType1_GLQ
# SalePrice is 0.434543238532 correlated with HeatingQC_Ex
# SalePrice is 0.504093675905 correlated with KitchenQual_Ex
# SalePrice is 0.321641108819 correlated with KitchenQual_Gd
# SalePrice is 0.33932872327 correlated with FireplaceQu_Gd
# SalePrice is 0.33596064721 correlated with GarageType_Attchd
# SalePrice is 0.419677967818 correlated with GarageFinish_Fin
# MSZoning_C (all) is 0.462171950209 correlated with Neighborhood_IDOTRR
# MSZoning_FV is 0.862807109977 correlated with Neighborhood_Somerst
# MSZoning_RL is 0.304561425221 correlated with GarageType_Attchd
# MSZoning_RM is 0.561880742826 correlated with Neighborhood_OldTown
# MSZoning_RM is 0.347207411524 correlated with Foundation_BrkTil
# MSZoning_RM is 0.323147321253 correlated with GarageType_Detchd
# Street_Grvl is 0.323264697765 correlated with ExterQual_Fa
# LotShape_IR3 is 0.315250914569 correlated with RoofMatl_ClyTile
# LandContour_Low is 0.35113499856 correlated with LandSlope_Mod
# LandContour_Low is 0.408068411574 correlated with LandSlope_Sev
# LandContour_Low is 0.39640547141 correlated with Neighborhood_ClearCr
# LandContour_Lvl is 0.533652225554 correlated with LandSlope_Gtl
# LandSlope_Sev is 0.358875845302 correlated with Neighborhood_ClearCr
# LandSlope_Sev is 0.301472542661 correlated with RoofStyle_Flat
# Neighborhood_Blmngtn is 0.349162370359 correlated with BldgType_TwnhsE
# Neighborhood_BrDale is 0.448614164273 correlated with BldgType_Twnhs
# Neighborhood_BrkSide is 0.306261237482 correlated with Foundation_BrkTil
# Neighborhood_ClearCr is 0.305714447764 correlated with RoofStyle_Flat
# Neighborhood_CollgCr is 0.354510104264 correlated with Exterior1st_VinylSd
# Neighborhood_CollgCr is 0.361652627967 correlated with Exterior2nd_VinylSd
# Neighborhood_CollgCr is 0.308225903409 correlated with BsmtQual_Gd
# Neighborhood_MeadowV is 0.519798754905 correlated with Exterior1st_CemntBd
# Neighborhood_MeadowV is 0.52429979486 correlated with Exterior2nd_CmentBd
# Neighborhood_NAmes is 0.402994609238 correlated with Foundation_CBlock
# Neighborhood_NAmes is 0.351157808634 correlated with BsmtQual_TA
# Neighborhood_NPkVill is 0.627945257087 correlated with Exterior2nd_Brk Cmn
# Neighborhood_NridgHt is 0.371100207021 correlated with MasVnrType_Stone
# Neighborhood_NridgHt is 0.417622947718 correlated with ExterQual_Ex
# Neighborhood_NridgHt is 0.462593771994 correlated with BsmtQual_Ex
# Neighborhood_OldTown is 0.364824167991 correlated with Foundation_BrkTil
# Condition1_PosN is 0.322545825719 correlated with Condition2_PosN
# Condition1_RRAn is 0.315162829699 correlated with Condition2_Feedr
# Condition2_PosA is 0.30047628713 correlated with HouseStyle_2.5Unf
# Condition2_PosA is 0.576954417056 correlated with ExterCond_Ex
# Condition2_RRAe is 0.706864413817 correlated with RoofStyle_Shed
# RoofStyle_Flat is 0.834913924148 correlated with RoofMatl_Tar&Grv
# RoofStyle_Mansard is 0.335387978206 correlated with RoofMatl_WdShake
# RoofStyle_Shed is 0.314816686501 correlated with RoofMatl_WdShake
# RoofMatl_WdShake is 0.314816686501 correlated with Exterior1st_Stone
# Exterior1st_AsbShng is 0.847916666667 correlated with Exterior2nd_AsbShng
# Exterior1st_AsphShn is 0.576954417056 correlated with Exterior2nd_AsphShn
# Exterior1st_BrkComm is 0.533605162943 correlated with Exterior2nd_Brk Cmn
# Exterior1st_BrkFace is 0.671889228073 correlated with Exterior2nd_BrkFace
# Exterior1st_CBlock is 1.0 correlated with Exterior2nd_CBlock
# Exterior1st_CemntBd is 0.974171084194 correlated with Exterior2nd_CmentBd
# Exterior1st_HdBoard is 0.88327139703 correlated with Exterior2nd_HdBoard
# Exterior1st_ImStucc is 0.315250914569 correlated with Exterior2nd_ImStucc
# Exterior1st_MetalSd is 0.973065193763 correlated with Exterior2nd_MetalSd

# %%
train_dummies = pd.get_dummies(train)
test_dummies = pd.get_dummies(test)

# %%
train_dummies.shape
# Out:
# (1460, 288)

# %%
test_dummies.shape
# Out:
# (1459, 273)

# %%
## there are some features in train set not in test set. We need to throw them. We can only use 
## features appear in both set

features_avail = [col for col in train_dummies if col in test_dummies]
X = train_dummies[features_avail]
print(X.shape)
y = train_dummies['SalePrice']
print(y.shape)
T = test_dummies[features_avail]

print(T.shape)
# Out:
# (1460, 272)
# (1460,)
# (1459, 272)

# %%
from sklearn import preprocessing
X_normalized = preprocessing.normalize(X)
T_normalized = preprocessing.normalize(T)

# %%
from sklearn import decomposition

n_eigens=30
X_reduced = decomposition.PCA(n_components=n_eigens).fit(X_normalized)
with plt.style.context('fivethirtyeight'):
    plt.figure(figsize=(8, 5));
    plt.title('Cumulative Explained Variance over EigenFace');
    plt.plot(X_reduced.explained_variance_ratio_.cumsum());

# %%
X_reduced = decomposition.PCA(n_components=10).fit_transform(X_normalized)
T_reduced = decomposition.PCA(n_components=10).fit_transform(T_normalized)

# %%
from sklearn.model_selection import cross_val_score

def rmse_cv(model,X_train,y):
    rmse= np.sqrt(-cross_val_score(model, X_train, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
from sklearn import neighbors

n_neighbors = 5

knn = neighbors.KNeighborsRegressor(n_neighbors, weights='distance')
print(rmse_cv(knn,X_normalized,y))
# Out:
# [ 43188.54061887  41945.701274    47748.85054399  37629.87783641
#   52097.79190402]

# %%
knn.fit(X_normalized,y)
knn.predict(X_normalized)
# Out:
# array([ 208500.,  181500.,  223500., ...,  266500.,  142125.,  147500.])

# %%
test.ix[pd.isnull(test['Utilities'])]
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 455  1916          30      NaN        109.0    21780   Grvl      Reg
# 485  1946          20       RL          NaN    31220   Pave      IR1
#
#     LandContour Utilities LotConfig      ...       OpenPorchSF EnclosedPorch  \
# 455         Lvl       NaN    Inside      ...                24             0
# 485         Bnk       NaN       FR2      ...                 0           144
#
#     3SsnPorch ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  \
# 455         0           0        0       0       3    2009     ConLD
# 485         0           0        0     750       5    2008        WD
#
#      SaleCondition
# 455         Normal
# 485         Normal
#
# [2 rows x 76 columns]

# %%
pd.DataFrame(train.isnull().sum(),columns = ['missingVal']).query('missingVal>0').sort_values(by = 'missingVal',ascending = False)
# Out:
#              missingVal
# FireplaceQu         690
# LotFrontage         259
# GarageYrBlt          81
# MasVnrType            8
# MasVnrArea            8
# Electrical            1

# %%
type(np.nan)
# Out:
# float

# %%
train['LotFrontage'].hist()

# %%
print(train['GarageYrBlt'].unique())
print('The newest house built in %d and the oldest built in %d'
      %(train['GarageYrBlt'].max(),train['GarageYrBlt'].min()))
# Out:
# [ 2003.  1976.  2001.  1998.  2000.  1993.  2004.  1973.  1931.  1939.
#   1965.  2005.  1962.  2006.  1960.  1991.  1970.  1967.  1958.  1930.
#   2002.  1968.  2007.  2008.  1957.  1920.  1966.  1959.  1995.  1954.
#   1953.    nan  1983.  1977.  1997.  1985.  1963.  1981.  1964.  1999.
#   1935.  1990.  1945.  1987.  1989.  1915.  1956.  1948.  1974.  2009.
#   1950.  1961.  1921.  1900.  1979.  1951.  1969.  1936.  1975.  1971.
#   1923.  1984.  1926.  1955.  1986.  1988.  1916.  1932.  1972.  1918.
#   1980.  1924.  1996.  1940.  1949.  1994.  1910.  1978.  1982.  1992.
#   1925.  1941.  2010.  1927.  1947.  1937.  1942.  1938.  1952.  1928.
#   1922.  1934.  1906.  1914.  1946.  1908.  1929.  1933.]
# The newest house built in 2010 and the oldest built in 1900

# %%
for col in cate_col_miss:
    print('%d classes in col %s'%(len(train[col].unique()), col))
# Out:
# 7 classes in col GarageType
# 4 classes in col GarageFinish
# 6 classes in col GarageQual
# 6 classes in col GarageCond
# 5 classes in col BsmtExposure
# 7 classes in col BsmtFinType2
# 7 classes in col BsmtFinType1
# 5 classes in col BsmtCond
# 5 classes in col BsmtQual
# 5 classes in col MasVnrType
# 6 classes in col Electrical

# %%
train['SalePrice'].hist()

# %%
train[train.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 5        6          50       RL         85.0    14115   Pave      IR1
# 7        8          60       RL          NaN    10382   Pave      IR1
# 10      11          20       RL         70.0    11200   Pave      Reg
# 12      13          20       RL          NaN    12968   Pave      IR2
# 14      15          20       RL          NaN    10920   Pave      IR1
# 15      16          45       RM         51.0     6120   Pave      Reg
# 16      17          20       RL          NaN    11241   Pave      IR1
# 17      18          90       RL         72.0    10791   Pave      Reg
# 18      19          20       RL         66.0    13695   Pave      Reg
# 19      20          20       RL         70.0     7560   Pave      Reg
# 24      25          20       RL          NaN     8246   Pave      IR1
# 26      27          20       RL         60.0     7200   Pave      Reg
# 29      30          30       RM         60.0     6324   Pave      IR1
# 30      31          70  C (all)         50.0     8500   Pave      Reg
# 31      32          20       RL          NaN     8544   Pave      IR1
# 32      33          20       RL         85.0    11049   Pave      Reg
# 36      37          20       RL        112.0    10859   Pave      Reg
# 38      39          20       RL         68.0     7922   Pave      Reg
# 39      40          90       RL         65.0     6040   Pave      Reg
# 42      43          85       RL          NaN     9180   Pave      IR1
# 43      44          20       RL          NaN     9200   Pave      IR1
# 44      45          20       RL         70.0     7945   Pave      Reg
# 47      48          20       FV         84.0    11096   Pave      Reg
# 48      49         190       RM         33.0     4456   Pave      Reg
# 49      50          20       RL         66.0     7742   Pave      Reg
# 50      51          60       RL          NaN    13869   Pave      IR2
# 52      53          90       RM        110.0     8472   Grvl      IR2
# 56      57         160       FV         24.0     2645   Pave      Reg
# 57      58          60       RL         89.0    11645   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1408  1409          70       RM         60.0     7740   Pave      Reg
# 1410  1411          60       RL         79.0    12420   Pave      Reg
# 1411  1412          50       RL         80.0     9600   Pave      Reg
# 1412  1413          90       RL         60.0     7200   Pave      Reg
# 1416  1417         190       RM         60.0    11340   Pave      Reg
# 1417  1418          60       RL          NaN    16545   Pave      IR1
# 1418  1419          20       RL         71.0     9204   Pave      Reg
# 1419  1420          20       RL          NaN    16381   Pave      IR1
# 1422  1423         120       RM         37.0     4435   Pave      Reg
# 1423  1424          80       RL          NaN    19690   Pave      IR1
# 1424  1425          20       RL          NaN     9503   Pave      Reg
# 1425  1426          20       RL         80.0    10721   Pave      IR1
# 1429  1430          20       RL          NaN    12546   Pave      IR1
# 1431  1432         120       RL          NaN     4928   Pave      IR1
# 1432  1433          30       RL         60.0    10800   Pave      Reg
# 1436  1437          20       RL         60.0     9000   Pave      Reg
# 1438  1439          20       RM         90.0     7407   Pave      Reg
# 1441  1442         120       RM          NaN     4426   Pave      Reg
# 1443  1444          30       RL          NaN     8854   Pave      Reg
# 1444  1445          20       RL         63.0     8500   Pave      Reg
# 1445  1446          85       RL         70.0     8400   Pave      Reg
# 1446  1447          20       RL          NaN    26142   Pave      IR1
# 1448  1449          50       RL         70.0    11767   Pave      Reg
# 1449  1450         180       RM         21.0     1533   Pave      Reg
# 1450  1451          90       RL         60.0     9000   Pave      Reg
# 1452  1453         180       RM         35.0     3675   Pave      Reg
# 1453  1454          20       RL         90.0    17217   Pave      Reg
# 1454  1455          20       FV         62.0     7500   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig    ...     EnclosedPorch 3SsnPorch  \
# 0            Lvl    AllPub    Inside    ...                 0         0
# 5            Lvl    AllPub    Inside    ...                 0       320
# 7            Lvl    AllPub    Corner    ...               228         0
# 10           Lvl    AllPub    Inside    ...                 0         0
# 12           Lvl    AllPub    Inside    ...                 0         0
# 14           Lvl    AllPub    Corner    ...               176         0
# 15           Lvl    AllPub    Corner    ...                 0         0
# 16           Lvl    AllPub   CulDSac    ...                 0         0
# 17           Lvl    AllPub    Inside    ...                 0         0
# 18           Lvl    AllPub    Inside    ...                 0         0
# 19           Lvl    AllPub    Inside    ...                 0         0
# 24           Lvl    AllPub    Inside    ...                 0         0
# 26           Lvl    AllPub    Corner    ...                 0         0
# 29           Lvl    AllPub    Inside    ...                87         0
# 30           Lvl    AllPub    Inside    ...               172         0
# 31           Lvl    AllPub   CulDSac    ...                 0         0
# 32           Lvl    AllPub    Corner    ...                 0         0
# 36           Lvl    AllPub    Corner    ...                 0         0
# 38           Lvl    AllPub    Inside    ...                 0         0
# 39           Lvl    AllPub    Inside    ...                 0         0
# 42           Lvl    AllPub   CulDSac    ...                 0         0
# 43           Lvl    AllPub   CulDSac    ...                 0         0
# 44           Lvl    AllPub    Inside    ...                 0         0
# 47           Lvl    AllPub    Inside    ...                 0         0
# 48           Lvl    AllPub    Inside    ...               102         0
# 49           Lvl    AllPub    Inside    ...                 0         0
# 50           Lvl    AllPub    Corner    ...                 0         0
# 52           Bnk    AllPub    Corner    ...                 0         0
# 56           Lvl    AllPub    Inside    ...                 0         0
# 57           Lvl    AllPub    Corner    ...                 0         0
# ...          ...       ...       ...    ...               ...       ...
# 1408         Lvl    AllPub    Inside    ...                 0         0
# 1410         Lvl    AllPub    Inside    ...                 0         0
# 1411         Lvl    AllPub    Inside    ...                 0         0
# 1412         Lvl    AllPub    Inside    ...                 0         0
# 1416         Lvl    AllPub    Inside    ...               114         0
# 1417         Lvl    AllPub    Inside    ...                 0         0
# 1418         Lvl    AllPub    Inside    ...                 0         0
# 1419         Lvl    AllPub    Inside    ...               216         0
# 1422         Lvl    AllPub    Inside    ...                 0         0
# 1423         Lvl    AllPub   CulDSac    ...                 0         0
# 1424         Lvl    AllPub    Inside    ...                 0         0
# 1425         Lvl    AllPub    Inside    ...                 0         0
# 1429         Lvl    AllPub    Corner    ...                99         0
# 1431         Lvl    AllPub    Inside    ...                 0         0
# 1432         Lvl    AllPub    Inside    ...                 0         0
# 1436         Lvl    AllPub       FR2    ...                 0         0
# 1438         Lvl    AllPub    Inside    ...               158         0
# 1441         Lvl    AllPub    Inside    ...                 0         0
# 1443         Lvl    AllPub    Inside    ...                 0         0
# 1444         Lvl    AllPub       FR2    ...                 0         0
# 1445         Lvl    AllPub    Inside    ...               252         0
# 1446         Lvl    AllPub   CulDSac    ...                 0         0
# 1448         Lvl    AllPub    Inside    ...                 0         0
# 1449         Lvl    AllPub    Inside    ...                 0         0
# 1450         Lvl    AllPub       FR2    ...                 0         0
# 1452         Lvl    AllPub    Inside    ...                 0         0
# 1453         Lvl    AllPub    Inside    ...                 0         0
# 1454         Lvl    AllPub    Inside    ...                 0         0
# 1458         Lvl    AllPub    Inside    ...               112         0
# 1459         Lvl    AllPub    Inside    ...                 0         0
#
#      ScreenPorch PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  \
# 0              0        0       0      2    2008        WD         Normal
# 5              0        0     700     10    2009        WD         Normal
# 7              0        0     350     11    2009        WD         Normal
# 10             0        0       0      2    2008        WD         Normal
# 12           176        0       0      9    2008        WD         Normal
# 14             0        0       0      5    2008        WD         Normal
# 15             0        0       0      7    2007        WD         Normal
# 16             0        0     700      3    2010        WD         Normal
# 17             0        0     500     10    2006        WD         Normal
# 18             0        0       0      6    2008        WD         Normal
# 19             0        0       0      5    2009       COD        Abnorml
# 24             0        0       0      5    2010        WD         Normal
# 26             0        0       0      5    2010        WD         Normal
# 29             0        0       0      5    2008        WD         Normal
# 30             0        0       0      7    2008        WD         Normal
# 31             0        0       0      6    2008        WD         Normal
# 32             0        0       0      1    2008        WD         Normal
# 36             0        0       0      6    2009        WD         Normal
# 38             0        0       0      1    2010        WD        Abnorml
# 39             0        0       0      6    2008        WD        AdjLand
# 42             0        0       0     12    2007        WD         Normal
# 43             0        0       0      7    2008        WD         Normal
# 44             0        0       0      5    2006        WD         Normal
# 47             0        0       0      7    2007        WD         Normal
# 48             0        0       0      6    2009       New        Partial
# 49             0        0       0      1    2007        WD         Normal
# 50             0        0       0      7    2007        WD         Normal
# 52             0        0       0      5    2010        WD         Normal
# 56             0        0       0      8    2009        WD        Abnorml
# 57             0        0       0      8    2006        WD         Normal
# ...          ...      ...     ...    ...     ...       ...            ...
# 1408         168        0       0      6    2010        WD         Normal
# 1410           0        0       0      6    2009        WD         Normal
# 1411           0        0       0      9    2009        WD         Normal
# 1412           0        0       0      6    2009        WD         Normal
# 1416           0        0       0      4    2010        WD         Normal
# 1417           0        0       0      5    2009        WD         Normal
# 1418           0        0       0      8    2008       COD         Normal
# 1419           0        0       0     12    2006        WD         Normal
# 1422           0        0       0      3    2008        WD         Normal
# 1423           0      738       0      8    2006        WD         Alloca
# 1424           0        0       0      6    2007        WD         Normal
# 1425           0        0       0     10    2008        WD         Normal
# 1429           0        0       0      4    2007        WD         Normal
# 1431           0        0       0     10    2009        WD         Normal
# 1432           0        0       0      8    2007        WD         Normal
# 1436           0        0       0      5    2007        WD         Normal
# 1438           0        0       0      4    2010        WD         Normal
# 1441           0        0       0      5    2008        WD         Normal
# 1443          40        0       0      5    2009        WD         Normal
# 1444           0        0       0     11    2007        WD         Normal
# 1445           0        0       0      5    2007        WD         Normal
# 1446           0        0       0      4    2010        WD         Normal
# 1448           0        0       0      5    2007        WD         Normal
# 1449           0        0       0      8    2006        WD        Abnorml
# 1450           0        0       0      9    2009        WD         Normal
# 1452           0        0       0      5    2006        WD         Normal
# 1453           0        0       0      7    2006        WD        Abnorml
# 1454           0        0       0     10    2009        WD         Normal
# 1458           0        0       0      4    2010        WD         Normal
# 1459           0        0       0      6    2008        WD         Normal
#
#       SalePrice
# 0        208500
# 5        143000
# 7        200000
# 10       129500
# 12       144000
# 14       157000
# 15       132000
# 16       149000
# 17        90000
# 18       159000
# 19       139000
# 24       154000
# 26       134800
# 29        68500
# 30        40000
# 31       149350
# 32       179900
# 36       145000
# 38       109000
# 39        82000
# 42       144000
# 43       130250
# 44       141000
# 47       249700
# 48       113000
# 49       127000
# 50       177000
# 52       110000
# 56       172500
# 57       196500
# ...         ...
# 1408     125500
# 1410     230000
# 1411     140000
# 1412      90000
# 1416     122500
# 1417     340000
# 1418     124000
# 1419     223000
# 1422     136500
# 1423     274970
# 1424     144000
# 1425     142000
# 1429     182900
# 1431     143750
# 1432      64500
# 1436     120500
# 1438     149700
# 1441     149300
# 1443     121000
# 1444     179600
# 1445     129000
# 1446     157900
# 1448     112000
# 1449      92000
# 1450     136000
# 1452     145000
# 1453      84500
# 1454     185000
# 1458     142125
# 1459     147500
#
# [877 rows x 77 columns]
